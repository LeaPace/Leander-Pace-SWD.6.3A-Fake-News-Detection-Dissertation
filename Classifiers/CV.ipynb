# %%
import numpy as np
import pandas as pd

from sklearn import pipeline,ensemble,preprocessing,feature_extraction,metrics

# %%
train = pd.read_csv("../dataset/PreProcessedLiar/train3.csv")
test = pd.read_csv("../dataset/PreProcessedLiar/test3.csv")

# %%
dataset = train.append(test, ignore_index=True)

# %%
dataset
# Out:
#        articleId                                  cleaned_statement  \
# 0           2635  say anni list polit group support trimest abor...
# 1          10540  declin coal start start natur take start begin...
# 2            324  hillari clinton agre john mccain vote georg bu...
# 3           1123  health care reform legisl like mandat free cha...
# 4           9028  econom turnaround start term crist say econom ...
# ...          ...                                                ...
# 11502       7334  say budget provide highest state fund level hi...
# 11503       9788  make pledge obama say budget soon propose look...
# 11504      10710  early edward kennedy secretly offer help sovie...
# 11505       3186  say permit languish strickland director day po...
# 11506       6743  say governor go state talk fund income benefit...
#
#              label
# 0            false
# 1        half-true
# 2      mostly-true
# 3            false
# 4        half-true
# ...            ...
# ...

# %%
corpus = dataset['cleaned_statement']

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vec = CountVectorizer()

# tokenize, build vocab and encode training data
word_count_cvec = count_vec.fit_transform(corpus)

word_count_cvec.shape
# Out:
# (11507, 17538)

# %%
#print(count_vec.get_feature_names())

# %%
vector = count_vec.transform(corpus)

# %%
matrix = count_vec.fit_transform(corpus)
counts = pd.DataFrame(matrix.toarray(), index=[corpus], columns=count_vec.get_feature_names())
counts
# Out:
#                                                     aaan  aaau  aamend  aaron  \
# cleaned_statement
# say anni list polit group support trimest abort...     0     0       0      0
# declin coal start start natur take start begin ...     0     0       0      0
# hillari clinton agre john mccain vote georg bus...     0     0       0      0
# health care reform legisl like mandat free chan...     0     0       0      0
# econom turnaround start term crist say econom t...     0     0       0      0
# ...                                                  ...   ...     ...    ...
# say budget provide highest state fund level his...     0     0       0      0
# make pledge obama say budget soon propose look ...     0     0       0      0
# early edward kennedy secretly offer help soviet...     0     0       0      0
# say permit languish strickland director day poi...     0     0       0      0
# say governor go state talk fund income benefit ...     0     0       0      0
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tf_transformer = TfidfTransformer(use_idf=True).fit(matrix)
word_count_cvec_tf = tf_transformer.transform(matrix)
word_count_cvec_tf.shape
# Out:
# (11507, 17538)

# %%
df1 = pd.DataFrame(word_count_cvec_tf.toarray(), columns=count_vec.get_feature_names(), index=[corpus])
df1.sample(5)
# Out:
#                                                     aaan  aaau  aamend  aaron  \
# cleaned_statement
# hillari clinton set deadlin withdraw want preci...   0.0   0.0     0.0    0.0
# wisconsin literally break republican take offic...   0.0   0.0     0.0    0.0
# today time year master lock union plant milwauk...   0.0   0.0     0.0    0.0
# say state check spend habit milwauke counti boa...   0.0   0.0     0.0    0.0
# spend billion year make sure feder govern immig...   0.0   0.0     0.0    0.0
#
#                                                     aarp  aback  abandon  \
# cleaned_statement
# hillari clinton set deadlin withdraw want preci...   0.0    0.0      0.0
# wisconsin literally break republican take offic...   0.0    0.0      0.0
# today time year master lock union plant milwauk...   0.0    0.0      0.0
# say state check spend habit milwauke counti boa...   0.0    0.0      0.0
# spend billion year make sure feder govern immig...   0.0    0.0      0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity(df1[0:1], df1)
# Out:
# array([[1.00000000e+00, 8.92482434e-04, 3.07844123e-02, ...,
#         1.84986451e-03, 1.07409818e-03, 1.71404986e-03]])
